# %% [markdown]
# # Build the script
# ### step 1 : create the file structure

# %%
import os
os.makedirs("src",exist_ok=True)
os.makedirs("outputs",exist_ok=True)

# %% [markdown]
# ###step 2 : write the full script

# %%
# src/generate.py
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import argparse
import os
from datetime import datetime

def load_model(model_name="distilgpt2"):
    print(f"Loading model: {model_name}")
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(model_name)
    model.eval()
    return tokenizer, model

def generate(prompt, tokenizer, model, temperature=0.7, top_k=50, top_p=0.9, max_new_tokens=100):
    inputs = tokenizer(prompt, return_tensors="pt")
    with torch.no_grad():
        outputs = model.generate(
            inputs["input_ids"],
            attention_mask=inputs["attention_mask"],
            pad_token_id=tokenizer.eos_token_id,
            max_new_tokens=max_new_tokens,
            do_sample=True,
            temperature=temperature,
            top_k=top_k,
            top_p=top_p
        )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

def save_output(prompt, output, params, filepath="outputs/generation_examples.txt"):
    os.makedirs("outputs", exist_ok=True)
    with open(filepath, "a") as f:
        f.write(f"\n{'='*50}\n")
        f.write(f"Timestamp : {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
        f.write(f"Prompt    : {prompt}\n")
        f.write(f"Params    : {params}\n")
        f.write(f"Output    : {output}\n")

def main():
    parser = argparse.ArgumentParser(description="LLM Text Generation Script")
    parser.add_argument("--prompt", type=str, required=True, help="Input prompt")
    parser.add_argument("--temperature", type=float, default=0.7)
    parser.add_argument("--top_k", type=int, default=50)
    parser.add_argument("--top_p", type=float, default=0.9)
    parser.add_argument("--max_new_tokens", type=int, default=100)
    parser.add_argument("--model", type=str, default="distilgpt2")
    args = parser.parse_args()

    tokenizer, model = load_model(args.model)

    params = {
        "temperature": args.temperature,
        "top_k": args.top_k,
        "top_p": args.top_p,
        "max_new_tokens": args.max_new_tokens
    }

    print(f"\nPrompt: {args.prompt}")
    output = generate(args.prompt, tokenizer, model, **params)
    print(f"\nGenerated:\n{output}")

    save_output(args.prompt, output, params)
    print(f"\nSaved to outputs/generation_examples.txt")

if __name__ == "__main__":
    main()
# Out:
# Loading model: distilgpt2
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Prompt: Neural networks work by
#
# Generated:
# Neural networks work by using a network of networks of neurons to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode
#
# Saved to outputs/generation_examples.txt

# %%
import os
os.makedirs("src", exist_ok=True)
os.makedirs("outputs", exist_ok=True)

script = '''
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import argparse
import os
from datetime import datetime

def load_model(model_name="distilgpt2"):
    print(f"Loading model: {model_name}")
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(model_name)
    model.eval()
    return tokenizer, model

def generate(prompt, tokenizer, model, temperature=0.7, top_k=50, top_p=0.9, max_new_tokens=100):
    inputs = tokenizer(prompt, return_tensors="pt")
    with torch.no_grad():
        outputs = model.generate(
            inputs["input_ids"],
            attention_mask=inputs["attention_mask"],
            pad_token_id=tokenizer.eos_token_id,
            max_new_tokens=max_new_tokens,
            do_sample=True,
            temperature=temperature,
            top_k=top_k,
            top_p=top_p
        )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

def save_output(prompt, output, params, filepath="outputs/generation_examples.txt"):
    os.makedirs("outputs", exist_ok=True)
    with open(filepath, "a") as f:
        f.write(f"\\n{'='*50}\\n")
        f.write(f"Timestamp : {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\\n")
        f.write(f"Prompt    : {prompt}\\n")
        f.write(f"Params    : {params}\\n")
        f.write(f"Output    : {output}\\n")

def main():
    parser = argparse.ArgumentParser(description="LLM Text Generation Script")
    parser.add_argument("--prompt", type=str, required=True)
    parser.add_argument("--temperature", type=float, default=0.7)
    parser.add_argument("--top_k", type=int, default=50)
    parser.add_argument("--top_p", type=float, default=0.9)
    parser.add_argument("--max_new_tokens", type=int, default=100)
    parser.add_argument("--model", type=str, default="distilgpt2")
    args = parser.parse_args()

    tokenizer, model = load_model(args.model)

    params = {
        "temperature": args.temperature,
        "top_k": args.top_k,
        "top_p": args.top_p,
        "max_new_tokens": args.max_new_tokens
    }

    print(f"\\nPrompt: {args.prompt}")
    output = generate(args.prompt, tokenizer, model, **params)
    print(f"\\nGenerated:\\n{output}")

    save_output(args.prompt, output, params)
    print(f"\\nSaved to outputs/generation_examples.txt")

if __name__ == "__main__":
    main()
'''

with open("src/generate.py", "w") as f:
    f.write(script)

print("File created successfully at src/generate.py")
# Out:
# File created successfully at src/generate.py

# %% [markdown]
# ### step 3 : tests

# %%
# In a notebook cell — simulates CLI
import sys
sys.argv = [
    "generate.py",
    "--prompt", "The future of machine learning is",
    "--temperature", "0.7",
    "--max_new_tokens", "80"
]

exec(open("src/generate.py").read())
# Out:
# Loading model: distilgpt2
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Prompt: The future of machine learning is
#
# Generated:
# The future of machine learning is not over. Machine learning is a major challenge, and will need to be done in a timely and efficient way, as it has been a long time since we began computing.
#
#
#
# The best way to achieve this is to create a simple and efficient machine learning system that can be used to build and implement machine learning systems.
# In this article I'll show you the various techniques and techniques
#
# Saved to outputs/generation_examples.txt

# %%
# Test 2
sys.argv = ["generate.py", "--prompt", "Neural networks work by", "--temperature", "0.3"]
exec(open("src/generate.py").read())

# Test 3
sys.argv = ["generate.py", "--prompt", "In 2030, AI will", "--temperature", "1.2", "--top_p", "0.85"]
exec(open("src/generate.py").read())
# Out:
# Loading model: distilgpt2
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Prompt: Neural networks work by
#
# Generated:
# Neural networks work by using a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of
#
# Saved to outputs/generation_examples.txt
# Loading model: distilgpt2
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Prompt: In 2030, AI will
#
# Generated:
# In 2030, AI will be a new frontier.
#
#
#
# But the latest assessment by China is the most pessimistic on the country's future.
#
#
# According to official news agency Xinhua, the country's future is far from assured.
# It estimates that the number of jobs and the number of new jobs will fall by a half in the year to 2025.
# The government is also considering a reduction in the amount of new businesses and job training for the country's new workforce.
# But experts believe that the
#
# Saved to outputs/generation_examples.txt

# %%
# Test 2
sys.argv = ["generate.py", "--prompt", "Neural networks work by", "--temperature", "0.3"]
exec(open("src/generate.py").read())

# Test 3
sys.argv = ["generate.py", "--prompt", "In 2030, AI will", "--temperature", "1.2", "--top_p", "0.85"]
exec(open("src/generate.py").read())
# Out:
# Loading model: distilgpt2
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Prompt: Neural networks work by
#
# Generated:
# Neural networks work by connecting a network of neurons to the brain. The network is a network of neurons that are connected to the brain. The network is a network of neurons that are connected to the brain. The network is a network of neurons that are connected to the brain. The network is a network of neurons that are connected to the brain. The network is a network of neurons that are connected to the brain. The network is a network of neurons that are connected to the brain. The network is a network of neurons
#
# Saved to outputs/generation_examples.txt
# Loading model: distilgpt2
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Prompt: In 2030, AI will
#
# Generated:
# In 2030, AI will not make up the world‏, but it will make the world’s biggest and most powerful AI, a major technology, which could make a lot more than ever before.
#
#
#
# ‏‏‏‏‏‏‏
# ‏‏‏‏
# Innovative AI could solve world problems ‏
# ‏
# ‏
# ‏‏
# ‏‏‏
# ‏‏‏
#
# Saved to outputs/generation_examples.txt

# %%
with open("outputs/generation_examples.txt", "r") as f:
    print(f.read())
# Out:
# ==================================================
# Timestamp : 2026-03-07 15:41:14
# Prompt    : Neural networks work by
# Params    : {'temperature': 0.3, 'top_k': 50, 'top_p': 0.9, 'max_new_tokens': 100}
# Output    : Neural networks work by connecting the brain to the brain, which is a part of the brain that is involved in learning and learning.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ==================================================
# Timestamp : 2026-03-07 15:42:45
# Prompt    : Neural networks work by
# Params    : {'temperature': 0.3, 'top_k': 50, 'top_p': 0.9, 'max_new_tokens': 100}
# Output    : Neural networks work by using a network of networks of neurons to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode the information that is needed to encode
#
# ==================================================
# Timestamp : 2026-03-07 15:45:37
# Prompt    : The future of machine learning is
# Params    : {'temperature': 0.7, 'top_k': 50, 'top_p': 0.9, 'max_new_tokens': 80}
# Output    : The future of machine learning is not over. Machine learning is a major challenge, and will need to be done in a timely and efficient way, as it has been a long time since we began computing.
#
#
#
# The best way to achieve this is to create a simple and efficient machine learning system that can be used to build and implement machine learning systems.
# In this article I'll show you the various techniques and techniques
#
# ==================================================
# Timestamp : 2026-03-07 15:45:43
# Prompt    : Neural networks work by
# Params    : {'temperature': 0.3, 'top_k': 50, 'top_p': 0.9, 'max_new_tokens': 100}
# Output    : Neural networks work by using a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of networks that are connected to a network of
#
# ==================================================
# Timestamp : 2026-03-07 15:45:49
# Prompt    : In 2030, AI will
# Params    : {'temperature': 1.2, 'top_k': 50, 'top_p': 0.85, 'max_new_tokens': 100}
# Output    : In 2030, AI will be a new frontier.
#
#
#
# But the latest assessment by China is the most pessimistic on the country's future.
#
#
# According to official news agency Xinhua, the country's future is far from assured.
# It estimates that the number of jobs and the number of new jobs will fall by a half in the year to 2025.
# The government is also considering a reduction in the amount of new businesses and job training for the country's new workforce.
# But experts believe that the
#
# ==================================================
# Timestamp : 2026-03-07 15:45:54
# Prompt    : Neural networks work by
# Params    : {'temperature': 0.3, 'top_k': 50, 'top_p': 0.9, 'max_new_tokens': 100}
# Output    : Neural networks work by connecting a network of neurons to the brain. The network is a network of neurons that are connected to the brain. The network is a network of neurons that are connected to the brain. The network is a network of neurons that are connected to the brain. The network is a network of neurons that are connected to the brain. The network is a network of neurons that are connected to the brain. The network is a network of neurons that are connected to the brain. The network is a network of neurons
#
# ==================================================
# Timestamp : 2026-03-07 15:45:59
# Prompt    : In 2030, AI will
# Params    : {'temperature': 1.2, 'top_k': 50, 'top_p': 0.85, 'max_new_tokens': 100}
# Output    : In 2030, AI will not make up the world‏, but it will make the world’s biggest and most powerful AI, a major technology, which could make a lot more than ever before.
#
#
#
# ‏‏‏‏‏‏‏
# ‏‏‏‏
# Innovative AI could solve world problems ‏
# ‏
# ‏
# ‏‏
# ‏‏‏
# ‏‏‏
